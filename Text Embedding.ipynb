# %%
# !pip install langchain
# Out:
# ...
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/6a/ca/27a0131c50d4ea8877d6183c7a2aaf16660b17d9b35144bb75a7393639eb/langchain-0.0.353-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/ae/53/8c006de775834cd4ea64a445402dc195caeebb77dc76b7defb9b3887cb0d/dataclasses_json-0.6.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for langchain-community<0.1,>=0.0.2 from https://files.pythonhosted.org/packages/81/ac/4002f920066d13c50d93c3745f8a96c744a9413d2edefbf021dff0e8dcee/langchain_community-0.0.7-py3-none-any.whl.metadata
# ...

# %%
# !pip install openai
# Out:
# ...
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/e7/44/5ece9adb8b5943273c845a1e3200168b396f556051b7d2745995abf41584/openai-1.6.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/39/9b/4937d841aee9c2c8102d9a4eeb800c7dad25386caabb4a1bf5010df81a57/httpx-0.26.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/56/ba/78b0a99c4da0ff8b0f59defa2f13ca4668189b134bd9840b6202a93d9a0f/httpcore-1.0.2-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      --------------------- ------------------ 30.7/58.3 kB ? eta -:--:--
# ...

# %%
pip install tiktoken
#Encoding and decoding text for large language models (LLMs):
#It's designed to efficiently process and encode text into a format that LLMs can understand and generate text from such encoded representations.
# Out:
# ...
#   Obtaining dependency information for tiktoken from https://files.pythonhosted.org/packages/f1/62/73629527ff413c8ce20189d29eb52a91d6d4571e3214ef6d5a2c00ca4081/tiktoken-0.5.2-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/786.4 kB ? eta -:--:--
#    - -------------------------------------- 30.7/786.4 kB 1.3 MB/s eta 0:00:01
#    ---- ---------------------------------- 81.9/786.4 kB 907.3 kB/s eta 0:00:01
#    ----- ---------------------------------- 112.6/786.4 kB 1.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 235.5/786.4 kB 1.3 MB/s eta 0:00:01
#    -------------- ------------------------- 276.5/786.4 kB 1.2 MB/s eta 0:00:01
#    ------------------ --------------------- 368.6/786.4 kB 1.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 471.0/786.4 kB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 665.6/786.4 kB 1.7 MB/s eta 0:00:01
# ...

# %%
import os
os.environ["OPENAI_API_KEY"]="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"

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embeddings= OpenAIEmbeddings()

# %%
our_text="Hi Friend"

# %%
text_embedding = embeddings.embed_query(our_text)
#need to install ticktocken module/Package

# %%
print(f"our embedding is length{text_embedding}")
# Out:
# our embedding is length[-0.0076839627984764, 0.0034370423324685015, -0.00304856439266558, -0.026376996927168824, -0.016513606995324035, 0.014946525403216325, -0.03131527541255533, -0.011990142390242093, -0.012984382351841585, -0.009099602953812366, 0.013478210572909275, -0.023348184955540773, 0.010396723926310142, -0.011726767152741471, -0.005906182040823054, -0.00480988402335215, 0.04090212027400347, -0.020964641710429558, 0.007907831331256759, 0.005096304372944958, -0.02818111409098511, 0.01891031727936347, 0.014353932282993177, 0.009922649057602583, -0.02770703922227755, 0.0057843710982528095, 0.0033037088338521634, -0.0361086997059246, 0.014669982195464882, -0.017883155995153027, 0.01501236897976083, 0.008256803497662018, -0.016197557082852327, -0.0057349886486750806, -0.0039868374539006315, -0.01353746969866707, -0.0014666689504410227, 0.0002510291885487206, 0.004431282759729293, -0.019200029388688332, 0.025823908649020736, -0.002302884188635311, -0.0056428072689837325, -0.00499
# ...

# %% [markdown]
# # Use of embedding in real world example

# %%
#Importing latest langchain or openai module
# !pip install langchain==0.0.351
# !pip install openai==1.5.0

# %%
import os
os.environ["OPENAI_API_KEY"]="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"

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embeddings= OpenAIEmbeddings()

# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\taary\AI Codes\S_Codes\Data files\Data.xlsx")
print(df)
#r before the location is just raw string. Raw strings provide a way to include backslashes in strings without their special meanings.
# Out:
#      Words
# 0   School
# 1  College
# 2      Car
# 3     Bike
# 4    Apple
# 5   orange
# 6   Banana

# %%
df['embedding'] = df['Words'].apply(lambda x: embeddings.embed_query(x))
df.to_csv('word_embeddings.csv')
#This may not execute if you have not added your credit card with aopen api.

"""
Basically to increase the rate limit on API, openAI expects a payment method to be added which is a constraint from openai.
That’s the issue here.
I would suggest open source embeddings model for this, as it would be cost effective or free
"""
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df['embedding'] = df['Words'].apply(lambda x: embeddings.embed_query(x))
#       2 df.to_csv('word_embeddings.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# ...

# %% [markdown]
# ##Let's load the existing file, which contains the embeddings, so that we can save chargers by not hitting the API repeatedly

# %%
new_df = pd.read_csv(r'C:\Users\taary\AI Codes\S_Codes\Data files\word_embeddings.csv')
print(new_df)
# Out:
#     Unnamed: 0       Words                                          embedding
# 0            0    Elephant  [-0.017855134320424067, -0.008739002273680945,...
# 1            1        Lion  [-0.001514446088710819, -0.010011047775235735,...
# 2            2       Tiger  [-0.013417221828848814, -0.009594874215361255,...
# 3            3         Dog  [-0.000993324388174965, -0.01511439587442286, ...
# 4            4     Cricket  [0.003905495127549336, -0.007206682981601541, ...
# 5            5     Footbal  [-0.011442505362835323, -0.008127146122306163,...
# 6            6      Tennis  [-0.0229627046214536, 0.001620174408225852, 0....
# 7            7  Basketball  [-0.012690632047445981, -0.013235320727905299,...
# 8            8       Apple  [0.01447704940326135, -0.003934278727982006, -...
# 9            9      Orange  [0.02067122263312988, -0.029222075283705507, 9...
# 10          10      Banana  [-0.01299976590369686, -0.019983216193919837, ...

# %%
our_text="Mango"

# %%
text_embedding=embeddings.embed_query(our_text)

# %%
print(f"our embedding is{text_embedding}")
# Out:
# our embedding is[-0.0034055178024402504, -0.019832508079084012, 0.010472126941037748, -0.016190586154939363, 0.0063190565524752825, 0.008516989408102726, -0.025122882089670933, -0.014197111660624243, 0.0011077517098275838, -0.03307121898826952, -0.0011668530894996393, 0.00378248876467282, 0.0019183990702938407, 0.016842297734595155, -0.021621524677748083, 0.004792004222854956, 0.03268786055033912, -0.00819113268695228, 0.009385939422740512, -0.015756111147620468, -0.015960569974594066, 0.002780959863004022, 0.0014703466607885723, -0.012401707120601069, 0.004558793606168833, 0.00955206221965656, 0.024483948255378443, -0.01366040723981855, 0.01157748294002503, 0.002991808028320544, 0.0477922582556587, -0.01502772564520448, -0.004351139877193137, -0.009922643843546205, -0.017596240590382842, 0.004654633681312707, -0.0103251716934892, -0.006373365695559507, -0.006251968267043934, -0.018324624230153734, 0.014452685194341239, -0.008325309257814977, -0.015641102126125274, -0.018107387657816
# ...

# %%
# embeddings_utils class has been remove by OpenAi from 1.1.version, so we will use the code to find the cosine similarity :)

#from openai.embeddings_utils import cosine_similarity
#may not run because the above embedding has not executed due to credit limit


import numpy as np

#Creating a function which will help us with finding the cosine_similarity score
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

df["similarity score"] = df['embedding'].apply(lambda x: cosine_similarity(x, text_embedding))
print(df["similarity score"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'embedding'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.sort_values("similarity score", ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10328\3805755778.py in ?()
# ----> 1 df.sort_values("similarity score", ascending=False).head(10)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
# ...
